# %%
import os
import csv
import json
import glob
import nltk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_files = glob.glob("./clean_tweets/*.csv")

# %%
len(csv_files)
# Out:
# 888

# %%
def get_tweet_volumes():
    tweets = {}
    
    for file in csv_files:

# %%
df = pd.read_csv(csv_files[0], sep="\t")

# %%
df
# Out:
#                        id  created_at                               hashtags  \
# 0     1093317380518875136  2019-02-07                          ['#legionfx']
# 1     1093277634442735616  2019-02-06                                     []
# 2     1093270875397328896  2019-02-06                                     []
# 3     1093260651622002690  2019-02-06                                     []
# 4     1093260608114491414  2019-02-06                                     []
# 5     1093259658771529730  2019-02-06                  ['#alitabattleangel']
# 6     1093246281638707201  2019-02-06                                     []
# 7     1093229249249583104  2019-02-06                                     []
# 8     1093216626160398337  2019-02-06                       ['#oscarslunch']
# 9     1093207892658929664  2019-02-06                                     []
# 10    1093206948697247749  2019-02-06                                     []
# ...

# %%
df.loc[df["hashtags"] != "[]"]
# Out:
#                        id  created_at                               hashtags  \
# 0     1093317380518875136  2019-02-07                          ['#legionfx']
# 5     1093259658771529730  2019-02-06                  ['#alitabattleangel']
# 8     1093216626160398337  2019-02-06                       ['#oscarslunch']
# 11    1093205683066032129  2019-02-06               ['#globesdecristal2019']
# 17    1093161730849542144  2019-02-06                       ['#oscarslunch']
# 25    1092960324808921088  2019-02-06           ['#fashionweek', '#bravotv']
# 28    1092927247206486016  2019-02-05  ['#sotu', '#stateofthewom', '#herst']
# 31    1092914143043207168  2019-02-05             ['#fosseverdon', '#tca19']
# 43    1092876622707986432  2019-02-05                        ['#oscars2019']
# 46    1092869993010745345  2019-02-05                              ['#nyfw']
# 48    1092852030245425153  2019-02-05                           ['#hrcgala']
# ...
